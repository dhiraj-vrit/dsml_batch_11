# %%
number = -122
print(type(number))
# Out:
# <class 'int'>

# %%
num = 3.4
type(num)
# Out:
# float

# %%
com = 3+3j
type(com)
# Out:
# complex

# %%
a = 3.45
b = int(a)
b
# Out:
# 3

# %%
a = 40
b = 20
print(a+b)
print(a-b)
print(a*b)
print(a/b)
print(a**2)
print(a%6)
print(a//9)
# Out:
# 60
# 20
# 800
# 2.0
# 1600
# 4
# 4

# %%
print(a==b)
# Out:
# False

# %%
print(a!=b)
# Out:
# True

# %%
ab = "Hello"
bc = 'hello'
print(ab == bc)
# Out:
# False

# %%
text1 = "It's a sunny day" # clean
text2 = 'He said "Hello"' # clean
print(text1)
print(text2)
# Out:
# It's a sunny day
# He said "Hello"

# %%
print(text1+ " " + text2)
# Out:
# It's a sunny day He said "Hello"

# %%
print(text1*3)
# Out:
# It's a sunny dayIt's a sunny dayIt's a sunny day

# %%
data = "Python"
print(data[-1])
print(data[5])
# Out:
# n
# n

# %%
# data[start:end:step]
data[1:4]
# Out:
# 'yth'

# %%
data[1:4:3]
# Out:
# 'y'

# %%
data[:-4]
# Out:
# 'Py'

# %%
data[3:]
# Out:
# 'hon'

# %%
data1 = "Hello Python"
# "ello pytho"
data1[1:-1:3]
# Out:
# 'eoyo'

# %%
len(data1)
# Out:
# 12

# %%
data3 = "I am a boy"
print(data3.replace("boy","girl"))
# Out:
# I am a girl

# %%
data4 = "    Hello Python      "
data4.strip("Hello")
# Out:
# '    Hello Python      '

# %%
data5 = "image.png"

# %%
data5.endswith("png")
data5.
# Out:
# True

# %%
words = ["Python", "is", "awesome"]
result = " ".join(words)
result
# Out:
# 'Python is awesome'
